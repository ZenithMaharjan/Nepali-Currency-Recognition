# %%
import uuid
import os
import time
import cv2

# %%
IMAGES_PATH = os.path.join("Data" , "Images")
labels = ['5','10','100','1000','20','50','500']
number_imgs = 140

# %%
cap = cv2.VideoCapture(1)
# for label in labels:
#     print("Collecting images for {}".format(label))
#     time.sleep(5)
label = labels[6]

for img_num in range(number_imgs):
    print("Collecting images for {}, image number {}".format(label,img_num))

    ret , frame = cap.read()

    imgname = os.path.join(IMAGES_PATH , label + '.' + str(uuid.uuid1()) + '.jpg')
    cv2.imwrite(imgname,frame)
    cv2.imshow("Image Collection" , frame)
    time.sleep(1)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for 500, image number 0
# Collecting images for 500, image number 1
# Collecting images for 500, image number 2
# Collecting images for 500, image number 3
# Collecting images for 500, image number 4
# Collecting images for 500, image number 5
# Collecting images for 500, image number 6
# Collecting images for 500, image number 7
# Collecting images for 500, image number 8
# Collecting images for 500, image number 9
# Collecting images for 500, image number 10
# Collecting images for 500, image number 11
# Collecting images for 500, image number 12
# Collecting images for 500, image number 13
# Collecting images for 500, image number 14
# Collecting images for 500, image number 15
# Collecting images for 500, image number 16
# Collecting images for 500, image number 17
# Collecting images for 500, image number 18
# Collecting images for 500, image number 19
# Collecting images for 500, image number 20
# Collecting images for 500, image number 21
# Collecting images for 500, image number 22
# Collecting images for 500, image number 23
# Collecting images for 500, image number 24
# Collecting images for 500, image number 25
# Collecting images for 500, image number 26
# Collecting images for 500, image number 27
# Collecting images for 500, image number 28
# Collecting images for 500, image number 29
# Collecting images for 500, image number 30
# Collecting images for 500, image number 31
# Collecting images for 500, image number 32
# Collecting images for 500, image number 33
# Collecting images for 500, image number 34
# Collecting images for 500, image number 35
# Collecting images for 500, image number 36
# Collecting images for 500, image number 37
# Collecting images for 500, image number 38
# Collecting images for 500, image number 39
# Collecting images for 500, image number 40
# Collecting images for 500, image number 41
# Collecting images for 500, image number 42
# Collecting images for 500, image number 43
# Collecting images for 500, image number 44
# Collecting images for 500, image number 45
# Collecting images for 500, image number 46
# Collecting images for 500, image number 47
# Collecting images for 500, image number 48
# Collecting images for 500, image number 49
# Collecting images for 500, image number 50
# Collecting images for 500, image number 51
# Collecting images for 500, image number 52
# Collecting images for 500, image number 53
# Collecting images for 500, image number 54
# Collecting images for 500, image number 55
# Collecting images for 500, image number 56
# Collecting images for 500, image number 57
# Collecting images for 500, image number 58
# Collecting images for 500, image number 59
# Collecting images for 500, image number 60
# Collecting images for 500, image number 61
# Collecting images for 500, image number 62
# Collecting images for 500, image number 63
# Collecting images for 500, image number 64
# Collecting images for 500, image number 65
# Collecting images for 500, image number 66
# Collecting images for 500, image number 67
# Collecting images for 500, image number 68
# Collecting images for 500, image number 69
# Collecting images for 500, image number 70
# Collecting images for 500, image number 71
# Collecting images for 500, image number 72
# Collecting images for 500, image number 73
# Collecting images for 500, image number 74
# Collecting images for 500, image number 75
# Collecting images for 500, image number 76
# Collecting images for 500, image number 77
# Collecting images for 500, image number 78
# Collecting images for 500, image number 79
# Collecting images for 500, image number 80
# Collecting images for 500, image number 81
# Collecting images for 500, image number 82
# Collecting images for 500, image number 83
# Collecting images for 500, image number 84
# Collecting images for 500, image number 85
# Collecting images for 500, image number 86
# Collecting images for 500, image number 87
# Collecting images for 500, image number 88
# Collecting images for 500, image number 89
# Collecting images for 500, image number 90
# Collecting images for 500, image number 91
# Collecting images for 500, image number 92
# Collecting images for 500, image number 93
# Collecting images for 500, image number 94
# Collecting images for 500, image number 95
# Collecting images for 500, image number 96
# Collecting images for 500, image number 97
# Collecting images for 500, image number 98
# Collecting images for 500, image number 99
# Collecting images for 500, image number 100
# Collecting images for 500, image number 101
# Collecting images for 500, image number 102
# Collecting images for 500, image number 103
# Collecting images for 500, image number 104
# Collecting images for 500, image number 105
# Collecting images for 500, image number 106
# Collecting images for 500, image number 107
# Collecting images for 500, image number 108
# Collecting images for 500, image number 109
# Collecting images for 500, image number 110
# Collecting images for 500, image number 111
# Collecting images for 500, image number 112
# Collecting images for 500, image number 113
# Collecting images for 500, image number 114
# Collecting images for 500, image number 115
# Collecting images for 500, image number 116
# Collecting images for 500, image number 117
# Collecting images for 500, image number 118
# Collecting images for 500, image number 119
# Collecting images for 500, image number 120
# Collecting images for 500, image number 121
# Collecting images for 500, image number 122
# Collecting images for 500, image number 123
# Collecting images for 500, image number 124
# Collecting images for 500, image number 125
# Collecting images for 500, image number 126
# Collecting images for 500, image number 127
# Collecting images for 500, image number 128
# Collecting images for 500, image number 129
# Collecting images for 500, image number 130
# Collecting images for 500, image number 131
# Collecting images for 500, image number 132
# Collecting images for 500, image number 133
# Collecting images for 500, image number 134
# Collecting images for 500, image number 135
# Collecting images for 500, image number 136
# Collecting images for 500, image number 137
# Collecting images for 500, image number 138
# Collecting images for 500, image number 139
